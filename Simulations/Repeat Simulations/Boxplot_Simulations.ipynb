# %%
from matplotlib import pyplot as plt
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
result_1 = pd.read_csv('repeat_S1_3000.csv', header = None).to_numpy()
result_2 = pd.read_csv('repeat_S2_3000.csv', header = None).to_numpy()
result_3 = pd.read_csv('repeat_S4_3000.csv', header = None).to_numpy()

# %%
data = [result_1[0,:], result_1[2,:], result_1[4,:], result_1[6,:]]


fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['UTOPIA', 'LQR',
                    'Split_CF', 'SDP'])
 
# Adding title
plt.title("Simulation 1: Coverage")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %%
data = [result_1[1,:], result_1[3,:], result_1[5,:], result_1[7,:]]


fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['UTOPIA', 'LQR',
                    'Split_CF', 'SDP'])
 
# Adding title
plt.title("Simulation 1: Width")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show()

# %%
#### A simple code for both the boxplots together 

plt.subplot(1,2,1)
data = [result_1[0,:], result_1[2,:], result_1[4,:], result_1[6,:]]
plt.boxplot(data)
plt.subplot(1,2,2)
data = [result_1[1,:], result_1[3,:], result_1[5,:], result_1[7,:]]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe173d3db10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe173d3e050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe173d3d870>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fe173d3e590>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe173d3e830>,
# ...
#  'means': []}
