# %%
from all_functions import * 
from sklearn.decomposition import PCA
import copy
from scipy.linalg import eigh
from sklearn.linear_model import LinearRegression

# %%
"""
This new functions takes the following inputs: 

    name -- the name of the Y variables, should be within double quote
    ncomps -- number of principal components to be used 
    error_comps -- number of error components to be used 
    outlier_remove -- a logical variable indicating whether to remove outliers 
    
This function select the Y variable based on the input name, and set X as 
all other variables. 

"""
def FRED_MD_DATA_PREP(name, ncomps = 5, error_comps = 5, outlier_remove = False):
   
    """
    Read the entire data
    """
    
    data = pd.read_csv('Transformed_na_removed.csv')
    
    """
    Set the Y axis to be the column of given name in the input, 
    remove that column and set the rest of the matrix as X. 
    Finally, do PCA on the X matrix. 
    
    """
    
    Y_axis = name
    X = copy.deepcopy(data)
    X.pop(name)
    X = X.to_numpy()
    n_data = X.shape[0]
    Y = data[name].to_numpy()
    W, V = eigh(X @ X.T)
    F_hat = np.sqrt(n_data) * V[:,-ncomps:] # select last ncomps columns of V
    B_hat = (1/n_data) * (X.T @ F_hat)
    
    if error_comps > 0:
        
        """
        First we project out the space of principal components
        to estimate the idiosyncratic errors. 
        """
        
#         loadings = X.T @ X_pca @ np.linalg.inv(X_pca.T @ X_pca) # OLS of X on X.pca
#         errors = X - X_pca @ loadings.T # OLS residuals
        U_hat = X - (F_hat @ B_hat.T)
        model = LinearRegression()
        model.fit(F_hat, Y)
        Y_u = Y - model.predict(F_hat)
        
        
        """
            Next we apply conditional SURE independent screening to select the 
            idiosyncratic components.
        """
       
        def cor_cal(x):
            return np.corrcoef(x, Y_u)[0, 1]
        
        cor_vec = np.apply_along_axis(cor_cal, 0, U_hat)
        idx = np.argsort(-np.abs(cor_vec))
        errors_to_add = U_hat[:,idx[:error_comps]]
        Data = np.hstack([F_hat, errors_to_add, Y.reshape(-1, 1)])
    
    else:
        Data = np.hstack([F_hat, Y.reshape(-1, 1)])
    
    if outlier_remove:
        Q1 = np.percentile(Y, 25, method = 'midpoint')
        Q3 = np.percentile(Y, 75, method = 'midpoint')
        IQR = Q3 - Q1
        upper=Q3+1.5*IQR
        upper_array=np.array(Y<=upper)
        lower=Q1-1.5*IQR
        lower_array=np.array(Y>=lower)
        index_keep = upper_array & lower_array
        Data = Data[index_keep[:,0].tolist(),:]
        print("The number of data being removed is ", Y.shape[0]-Data.shape[0])
        
    return Data, Y_axis

# %%
def UTOPIA_FRED_MD_MULTIVARIATE(Data, shrink = True):
    train_idx = int(Data.shape[0] * 0.8)
    train_data, test_data = np.split(Data, [train_idx])
    X_pre = train_data[:,:-1]
    Y_pre = train_data[:,-1].reshape(-1,1)
    X_opt = train_data[:,:-1]
    Y_opt = train_data[:,-1].reshape(-1,1)
    X_adj = train_data[:,:-1]
    Y_adj = train_data[:,-1].reshape(-1,1)
    X_t = test_data[:,:-1]
    Y_t = test_data[:,-1].reshape(-1,1)


    n_pre = len(Y_pre)
    n_opt = len(Y_opt)
    n_adj = len(Y_adj)
    n_t = len(Y_t)

    # Obtain mean estimator
    known_mean = "False"
    if known_mean == "True":
        M_pre = np.zeros(n_pre).reshape(-1,1)
        M_opt = np.zeros(n_opt).reshape(-1,1)
        M_adj = np.zeros(n_adj).reshape(-1,1)
        M_t = np.zeros(n_t).reshape(-1,1)
    else:
        est_type = "NN1"
        M_pre, M_opt, M_adj, M_t = mean_est(est_type,X_pre,Y_pre,X_opt,X_adj,X_t)

    # Obtain variance estimator
    var_opt, var_adj, var_t = var_est(X_pre,Y_pre,M_pre,X_opt,X_adj,X_t,est_type ="NN1")


    # Obtain quantile estimators
    quantile = [0.05,0.35,0.65,0.95]
    m1,Q1_opt,Q1_adj,Q1_t = est_quantile("NN1",quantile[0],X_pre,Y_pre,X_opt,X_adj,X_t)
    m2,Q2_opt,Q2_adj,Q2_t = est_quantile("NN2",quantile[1],X_pre,Y_pre,X_opt,X_adj,X_t)
    m3,Q3_opt,Q3_adj,Q3_t = est_quantile("qrf",quantile[2],X_pre,Y_pre,X_opt,X_adj,X_t)
    m4,Q4_opt,Q4_adj,Q4_t = est_quantile("gb",quantile[3],X_pre,Y_pre,X_opt,X_adj,X_t)

    # construct estimator matrix
    E_opt = np.hstack(((Q1_opt-M_opt)**2, (Q2_opt-M_opt)**2, (Q3_opt-M_opt)**2, (Q4_opt-M_opt)**2, var_opt))
    E_opt = E_opt.T
    E_adj = np.hstack(((Q1_adj-M_adj)**2, (Q2_adj-M_adj)**2, (Q3_adj-M_adj)**2, (Q4_adj-M_adj)**2, var_adj))
    E_adj = E_adj.T
    E_t = np.hstack(((Q1_t-M_t)**2, (Q2_t-M_t)**2, (Q3_t-M_t)**2, (Q4_t-M_t)**2, var_t))
    E_t = E_t.T


    # solve optimization problem

    optimal_weight, V100_adj, V100_t= solve_opt(X_opt,Y_opt, M_opt, M_adj, M_t, X_adj, X_t, "aug", E_opt, E_adj, E_t)
    # opt_sol, V100_adj, V100_t = solve_opt(X_opt,Y_opt, M_opt, M_adj, M_t, X_adj, X_t, "rkhs_poly", degree = 2)
    # opt_sol, V100_adj, V100_t = solve_opt(X_opt,Y_opt, M_opt, M_adj, M_t, X_adj, X_t, "rkhs_rbf", sigma = 1)

    # adjust interval
    if shrink: 
        alpha = 0.05
        delta = interval_adj(X_adj,Y_adj,M_adj,V100_adj,alpha,stepsize = 0.001)

        # plot
        V_alpha_t = delta*V100_t
    else:
        V_alpha_t = V100_t
    
    coverage = (np.power(Y_t[:,0]-M_t[:,0], 2) <= V_alpha_t[:,0]).mean()
    bandwidth = np.mean(V_alpha_t[:,0])
    print("The overall coverage for UTOPIA is", coverage)
    print("Mean bandwidth on test data for UTOPIA is", bandwidth)
    return X_t,Y_t,M_t,V_alpha_t,coverage,bandwidth

# %%
def LQR_FRED_MD_MULTIVARIATE(Data):
    train_idx = int(Data.shape[0] * 0.8)
    train_data, test_data = np.split(Data, [train_idx])

    X_lin = train_data[:,:-1]
    Y_lin = train_data[:,-1].reshape(-1,1)
    y_lin = Y_lin[:,0]
    X_quantile = train_data[:,:-1]
    Y_quantile = train_data[:,-1].reshape(-1,1)
    X_test = test_data[:,:-1]
    Y_test = test_data[:,-1].reshape(-1,1)

    # Estimate the mean using NN1
    est_type = "NN1"
    M_quantile, M_test = mean_est_others(est_type,X_lin,Y_lin,X_quantile,X_test)

    # Estimate the quantile
    alpha = 0.05

    model_quantile = QuantileRegressor(quantile=1-(alpha/2), alpha=0, solver = 'highs')
    model_quantile.fit(X_quantile, (Y_quantile-M_quantile).reshape(-1))
    Q_test = model_quantile.predict(X_test)


    V_test = Q_test**2
    V_test = V_test.reshape(-1,1)
    coverage = (np.power(Y_test[:,0]-M_test[:,0], 2) <= V_test[:,0]).mean()
    bandwidth = np.mean(V_test[:,0])
    print("The overall coverage for LQR is", coverage)
    print("Mean bandwidth on test data for LQR is", bandwidth)
    return X_test,Y_test,M_test,V_test, coverage, bandwidth

# %%
def SplitCF_FRED_MD_MULTIVARIATE(Data): 
    train_idx = int(Data.shape[0] * 0.8)
    train_data, test_data = np.split(Data, [train_idx])


    X_lin = train_data[:,:-1]
    Y_lin = train_data[:,1].reshape(-1,1)
    y_lin = Y_lin[:,0]
    X_res = train_data[:,:-1]
    Y_res = train_data[:,1].reshape(-1,1)
    y_res = Y_res[:,0]
    X_test = test_data[:,:-1]
    Y_test = test_data[:,1].reshape(-1,1)
    y_test = Y_test[:,0]

    # Estimate the mean using NN1
    est_type = "NN1"
    Y_res_pred, M_test = mean_est_others(est_type,X_lin,Y_lin,X_res,X_test)
    y_res_pred = Y_res_pred[:,0]

    # Calculate the conformity scores
    residuals = np.abs(y_res - y_res_pred)

    alpha = 0.05  # 95% confidence level
    k = int((1 - alpha) * len(y_lin))
    residuals_sorted = np.sort(residuals)
    threshold = residuals_sorted[k]

    # Calculate the prediction interval
    v_test = (threshold**2)*np.ones(len(y_test))
    V_test = v_test.reshape(-1,1)
    coverage = (np.power(Y_test[:,0]-M_test[:,0], 2) <= V_test[:,0]).mean()
    bandwidth = np.mean(V_test[:,0])
    print("The overall coverage for SplitCF is", coverage)
    print("Mean bandwidth on test data for SplitCF is", bandwidth)
    return X_test,Y_test,M_test,V_test,coverage,bandwidth

# %%
Data, Y_axis = FRED_MD_DATA_PREP('FEDFUNDS', ncomps=2, error_comps=2)


X_t,Y_t,M_t,V_alpha_t,covarage,bandwidth = UTOPIA_FRED_MD_MULTIVARIATE(Data, shrink = True)
X_test,Y_test,M_test,V_test,covarage,bandwidth = LQR_FRED_MD_MULTIVARIATE(Data)
X_test,Y_test,M_test,V_test,coverage,bandwidth = SplitCF_FRED_MD_MULTIVARIATE(Data)
# Out:
# The overall coverage for UTOPIA is 0.989010989010989
# Mean bandwidth on test data for UTOPIA is 0.05000081006534005
# The overall coverage for LQR is 0.4175824175824176
# Mean bandwidth on test data for LQR is 0.002460689001458032
# The overall coverage for SplitCF is 0.6043956043956044
# Mean bandwidth on test data for SplitCF is 0.004344519265782366

# %%
data = pd.read_csv('Transformed_na_removed.csv')
col = data.columns

# %%
output_coverage = np.zeros((len(data.columns)-1, 3))
output_bandwidth = np.zeros((len(data.columns)-1, 3))

for j in range(1, len(data.columns)):
    idx = data.columns[j]
    Data, Y_axis = FRED_MD_DATA_PREP(idx, ncomps=2, error_comps=2)
    
    X_t,Y_t,M_t,V_alpha_t, coverage_utopia, bandwidth_utopia = UTOPIA_FRED_MD_MULTIVARIATE(Data, shrink = True)
    X_test,Y_test,M_test,V_test,coverage_lqr, bandwidth_lqr = LQR_FRED_MD_MULTIVARIATE(Data)
    X_test,Y_test,M_test,V_test, coverage_split, bandwidth_split = SplitCF_FRED_MD_MULTIVARIATE(Data)
    
    output_coverage[j,] = np.array([coverage_utopia, coverage_lqr, coverage_split]).reshape(-1)
    output_bandwidth[j,] = np.array([bandwidth_utopia, bandwidth_lqr, bandwidth_split]).reshape(-1)
    print(j, "th index is done!")
# Out:
# The overall coverage for UTOPIA is 0.6703296703296703
# Mean bandwidth on test data for UTOPIA is 0.00018222621644607435
# The overall coverage for LQR is 0.6153846153846154
# Mean bandwidth on test data for LQR is 0.000152136549915781
# The overall coverage for SplitCF is 0.5054945054945055
# Mean bandwidth on test data for SplitCF is 0.002352426249221485
# 1 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.00017330117484767128
# The overall coverage for LQR is 0.6373626373626373
# Mean bandwidth on test data for LQR is 0.00018883164663082753
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002344698801502436
# 2 th index is done!
# The overall coverage for UTOPIA is 0.6263736263736264
# Mean bandwidth on test data for UTOPIA is 0.0001913887330110964
# The overall coverage for LQR is 0.4065934065934066
# Mean bandwidth on test data for LQR is 0.00010354854292050874
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002342474412501553
# 3 th index is done!
# The overall coverage for UTOPIA is 0.8571428571428571
# Mean bandwidth on test data for UTOPIA is 0.00034666384385599684
# The overall coverage for LQR is 0.7142857142857143
# Mean bandwidth on test data for LQR is 0.0002087958056166355
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0022023345074150447
# 4 th index is done!
# The overall coverage for UTOPIA is 0.7472527472527473
# Mean bandwidth on test data for UTOPIA is 0.00024241925487979708
# The overall coverage for LQR is 0.8461538461538461
# Mean bandwidth on test data for LQR is 0.0003128177071691233
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023256706334015063
# 5 th index is done!
# The overall coverage for UTOPIA is 0.5054945054945055
# Mean bandwidth on test data for UTOPIA is 0.00020423033879771947
# The overall coverage for LQR is 0.5714285714285714
# Mean bandwidth on test data for LQR is 0.00015992315262880239
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.004143311828399258
# 6 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.6373626373626373
# Mean bandwidth on test data for UTOPIA is 0.0001917439449883254
# The overall coverage for LQR is 0.5164835164835165
# Mean bandwidth on test data for LQR is 0.00015594872958674447
# The overall coverage for SplitCF is 0.5274725274725275
# Mean bandwidth on test data for SplitCF is 0.00253358134283988
# 7 th index is done!
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.00017423132111903225
# The overall coverage for LQR is 0.4945054945054945
# Mean bandwidth on test data for LQR is 0.00011653714248864585
# The overall coverage for SplitCF is 0.5604395604395604
# Mean bandwidth on test data for SplitCF is 0.002937484375050804
# 8 th index is done!
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.00017597967070776224
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.0001956459362664035
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.0027187649571974036
# 9 th index is done!
# The overall coverage for UTOPIA is 0.7802197802197802
# Mean bandwidth on test data for UTOPIA is 0.0005725617324202413
# The overall coverage for LQR is 0.7582417582417582
# Mean bandwidth on test data for LQR is 0.0007586689659250095
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002418322903431729
# 10 th index is done!
# The overall coverage for UTOPIA is 0.8791208791208791
# Mean bandwidth on test data for UTOPIA is 0.00033593661136677204
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.00018219889808863165
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.0023817093351546706
# 11 th index is done!
# The overall coverage for UTOPIA is 0.7472527472527473
# Mean bandwidth on test data for UTOPIA is 0.00027596319099003634
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.0003813408753279489
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.002718766508264126
# 12 th index is done!
# The overall coverage for UTOPIA is 0.8681318681318682
# Mean bandwidth on test data for UTOPIA is 0.0003951853283186857
# The overall coverage for LQR is 0.5494505494505495
# Mean bandwidth on test data for LQR is 0.00012505578450703917
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.0024229585807396827
# 13 th index is done!
# The overall coverage for UTOPIA is 0.6043956043956044
# Mean bandwidth on test data for UTOPIA is 0.0001762202991678635
# The overall coverage for LQR is 0.6483516483516484
# Mean bandwidth on test data for LQR is 0.0001391297504310754
# The overall coverage for SplitCF is 0.6263736263736264
# Mean bandwidth on test data for SplitCF is 0.0029907980810145495
# 14 th index is done!
# The overall coverage for UTOPIA is 0.7802197802197802
# Mean bandwidth on test data for UTOPIA is 0.0003503729980474891
# The overall coverage for LQR is 0.6593406593406593
# Mean bandwidth on test data for LQR is 0.00020985350505507412
# The overall coverage for SplitCF is 0.6263736263736264
# Mean bandwidth on test data for SplitCF is 0.0030026951142655503
# 15 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.00017120442302250572
# The overall coverage for LQR is 0.5934065934065934
# Mean bandwidth on test data for LQR is 0.00013557045956591902
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002497015868411698
# 16 th index is done!
# The overall coverage for UTOPIA is 0.6813186813186813
# Mean bandwidth on test data for UTOPIA is 0.0037671543933901386
# The overall coverage for LQR is 0.9010989010989011
# Mean bandwidth on test data for LQR is 0.005200382339940132
# The overall coverage for SplitCF is 0.5494505494505495
# Mean bandwidth on test data for SplitCF is 0.0028308524593358255
# 17 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 0.0018839935499581574
# The overall coverage for LQR is 0.5824175824175825
# Mean bandwidth on test data for LQR is 0.0003848234880138811
# The overall coverage for SplitCF is 0.1978021978021978
# Mean bandwidth on test data for SplitCF is 0.002112603000229745
# 18 th index is done!
# The overall coverage for UTOPIA is 0.8351648351648352
# Mean bandwidth on test data for UTOPIA is 0.16136049132349636
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.12673260197783365
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.0024302368391702525
# 19 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 87787.74045912114
# The overall coverage for LQR is 0.7252747252747253
# Mean bandwidth on test data for LQR is 172404.14375127794
# The overall coverage for SplitCF is 0.17582417582417584
# Mean bandwidth on test data for SplitCF is 0.0016058582230645266
# 20 th index is done!
# The overall coverage for UTOPIA is 0.6813186813186813
# Mean bandwidth on test data for UTOPIA is 0.0009763256999081188
# The overall coverage for LQR is 0.7472527472527473
# Mean bandwidth on test data for LQR is 0.0007468237070635451
# The overall coverage for SplitCF is 0.43956043956043955
# Mean bandwidth on test data for SplitCF is 0.002411848020868719
# 21 th index is done!
# The overall coverage for UTOPIA is 0.4725274725274725
# Mean bandwidth on test data for UTOPIA is 0.00019043644326657724
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.00015093689693779957
# The overall coverage for SplitCF is 0.4175824175824176
# Mean bandwidth on test data for SplitCF is 0.0021477153727228774
# 22 th index is done!
# The overall coverage for UTOPIA is 0.7252747252747253
# Mean bandwidth on test data for UTOPIA is 0.0003745613487497655
# The overall coverage for LQR is 0.4065934065934066
# Mean bandwidth on test data for LQR is 0.00014980565094104256
# The overall coverage for SplitCF is 0.1978021978021978
# Mean bandwidth on test data for SplitCF is 0.0024154388276982366
# 23 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 0.09353450722939537
# The overall coverage for LQR is 0.7582417582417582
# Mean bandwidth on test data for LQR is 0.033391199397330776
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0025557220424547895
# 24 th index is done!
# The overall coverage for UTOPIA is 0.4835164835164835
# Mean bandwidth on test data for UTOPIA is 0.3999153957211763
# The overall coverage for LQR is 0.7032967032967034
# Mean bandwidth on test data for LQR is 1.470681836718242
# The overall coverage for SplitCF is 0.2087912087912088
# Mean bandwidth on test data for SplitCF is 0.002556421094407729
# 25 th index is done!
# The overall coverage for UTOPIA is 0.45054945054945056
# Mean bandwidth on test data for UTOPIA is 0.0033606567068217717
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.005449008629192852
# The overall coverage for SplitCF is 0.38461538461538464
# Mean bandwidth on test data for SplitCF is 0.002358863060836064
# 26 th index is done!
# The overall coverage for UTOPIA is 0.7142857142857143
# Mean bandwidth on test data for UTOPIA is 0.004471773978071193
# The overall coverage for LQR is 0.9340659340659341
# Mean bandwidth on test data for LQR is 0.01196329715911508
# The overall coverage for SplitCF is 0.5604395604395604
# Mean bandwidth on test data for SplitCF is 0.0027301351549240305
# 27 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 0.0015821616981925761
# The overall coverage for LQR is 0.8021978021978022
# Mean bandwidth on test data for LQR is 0.0006336462537227397
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002324741768381806
# 28 th index is done!
# The overall coverage for UTOPIA is 0.9120879120879121
# Mean bandwidth on test data for UTOPIA is 0.020730307089531514
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.010092572694380214
# The overall coverage for SplitCF is 0.42857142857142855
# Mean bandwidth on test data for SplitCF is 0.002213332501886377
# 29 th index is done!
# The overall coverage for UTOPIA is 0.8791208791208791
# Mean bandwidth on test data for UTOPIA is 0.012574633579905778
# The overall coverage for LQR is 0.8791208791208791
# Mean bandwidth on test data for LQR is 0.006187214601449225
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026019068475029218
# 30 th index is done!
# The overall coverage for UTOPIA is 0.6593406593406593
# Mean bandwidth on test data for UTOPIA is 0.003196134650168595
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.010034635241645119
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0024520417156302697
# 31 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.6043956043956044
# Mean bandwidth on test data for UTOPIA is 0.00019176768709165524
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.0001650301298554606
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002225867159971563
# 32 th index is done!
# The overall coverage for UTOPIA is 0.5604395604395604
# Mean bandwidth on test data for UTOPIA is 0.0001707406724241567
# The overall coverage for LQR is 0.6373626373626373
# Mean bandwidth on test data for LQR is 0.00017647150864270173
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.00228077117561467
# 33 th index is done!
# The overall coverage for UTOPIA is 0.8021978021978022
# Mean bandwidth on test data for UTOPIA is 0.0005915822157648058
# The overall coverage for LQR is 0.5934065934065934
# Mean bandwidth on test data for LQR is 0.00019506804028770973
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002234874954844452
# 34 th index is done!
# The overall coverage for UTOPIA is 0.7142857142857143
# Mean bandwidth on test data for UTOPIA is 0.00019627319232450204
# The overall coverage for LQR is 0.5274725274725275
# Mean bandwidth on test data for LQR is 0.00014699468345758288
# The overall coverage for SplitCF is 0.45054945054945056
# Mean bandwidth on test data for SplitCF is 0.002223975391762232
# 35 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.3956043956043956
# Mean bandwidth on test data for UTOPIA is 0.0001809992844129827
# The overall coverage for LQR is 0.5824175824175825
# Mean bandwidth on test data for LQR is 0.00018605690666764478
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0022949339188943767
# 36 th index is done!
# The overall coverage for UTOPIA is 0.6813186813186813
# Mean bandwidth on test data for UTOPIA is 0.0001756647745579485
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.00015301781254212582
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002302944557336688
# 37 th index is done!
# The overall coverage for UTOPIA is 0.4725274725274725
# Mean bandwidth on test data for UTOPIA is 0.0001922697259056958
# The overall coverage for LQR is 0.5054945054945055
# Mean bandwidth on test data for LQR is 0.000161452814228166
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0023029445577663053
# 38 th index is done!
# The overall coverage for UTOPIA is 0.4835164835164835
# Mean bandwidth on test data for UTOPIA is 0.00015548545078661558
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.00017264773799743088
# The overall coverage for SplitCF is 0.42857142857142855
# Mean bandwidth on test data for SplitCF is 0.0021413524119852554
# 39 th index is done!
# The overall coverage for UTOPIA is 0.5714285714285714
# Mean bandwidth on test data for UTOPIA is 0.00016144346692619708
# The overall coverage for LQR is 0.6153846153846154
# Mean bandwidth on test data for LQR is 0.00017968035918542493
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0021424582176195464
# 40 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.8681318681318682
# Mean bandwidth on test data for UTOPIA is 0.00021183629683086568
# The overall coverage for LQR is 0.5164835164835165
# Mean bandwidth on test data for LQR is 0.00013414281373989184
# The overall coverage for SplitCF is 0.45054945054945056
# Mean bandwidth on test data for SplitCF is 0.002189421361870305
# 41 th index is done!
# The overall coverage for UTOPIA is 0.7472527472527473
# Mean bandwidth on test data for UTOPIA is 0.00018633996147584213
# The overall coverage for LQR is 0.6043956043956044
# Mean bandwidth on test data for LQR is 0.0001637744703339571
# The overall coverage for SplitCF is 0.42857142857142855
# Mean bandwidth on test data for SplitCF is 0.002142533078551305
# 42 th index is done!
# The overall coverage for UTOPIA is 0.5934065934065934
# Mean bandwidth on test data for UTOPIA is 0.0001820779624825388
# The overall coverage for LQR is 0.5714285714285714
# Mean bandwidth on test data for LQR is 0.0001608566644647923
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0025011819959716484
# 43 th index is done!
# The overall coverage for UTOPIA is 0.5494505494505495
# Mean bandwidth on test data for UTOPIA is 0.0002057574472574117
# The overall coverage for LQR is 0.6483516483516484
# Mean bandwidth on test data for LQR is 0.00020162594751989575
# The overall coverage for SplitCF is 0.43956043956043955
# Mean bandwidth on test data for SplitCF is 0.0021365859093230633
# 44 th index is done!
# The overall coverage for UTOPIA is 0.4065934065934066
# Mean bandwidth on test data for UTOPIA is 75.93212692015288
# The overall coverage for LQR is 0.945054945054945
# Mean bandwidth on test data for LQR is 87.94330835939257
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.003919538125576414
# 45 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 0.04001463335616642
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.020728656119055406
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.002532039322039402
# 46 th index is done!
# The overall coverage for UTOPIA is 0.31868131868131866
# Mean bandwidth on test data for UTOPIA is 83.10462060948852
# The overall coverage for LQR is 0.9560439560439561
# Mean bandwidth on test data for LQR is 97.86444978990896
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.003911026910647195
# 47 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 7.477135000273648
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 2.6466812682683227
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026246657904166414
# 48 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 3.973740217869518
# The overall coverage for LQR is 0.08791208791208792
# Mean bandwidth on test data for LQR is 1.198248003037738
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026257054220080863
# 49 th index is done!
# The overall coverage for UTOPIA is 0.9560439560439561
# Mean bandwidth on test data for UTOPIA is 6.438885475197503
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 0.7361001339231906
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.004533480959541233
# 50 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 6.09271921220027
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 1.796847343699841
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002624994206737476
# 51 th index is done!
# The overall coverage for UTOPIA is 0.9120879120879121
# Mean bandwidth on test data for UTOPIA is 4.406346998573581
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 0.8523325053450401
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002625407853153772
# 52 th index is done!
# The overall coverage for UTOPIA is 0.978021978021978
# Mean bandwidth on test data for UTOPIA is 8.675295347664067
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 2.270892443397102
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026245732775104095
# 53 th index is done!
# The overall coverage for UTOPIA is 0.989010989010989
# Mean bandwidth on test data for UTOPIA is 4.615297335344167
# The overall coverage for LQR is 0.07692307692307693
# Mean bandwidth on test data for LQR is 1.1001888379840024
# The overall coverage for SplitCF is 0.45054945054945056
# Mean bandwidth on test data for SplitCF is 0.002572481270512527
# 54 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 5.685602284815125
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 0.9150552540818871
# The overall coverage for SplitCF is 0.5714285714285714
# Mean bandwidth on test data for SplitCF is 0.003470891612407455
# 55 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 5.253053375829104
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 1.3815219068947353
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026250072143390035
# 56 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 4.203970415235543
# The overall coverage for LQR is 0.0
# Mean bandwidth on test data for LQR is 0.7941019956458616
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0026252752267016707
# 57 th index is done!
# The overall coverage for UTOPIA is 0.8241758241758241
# Mean bandwidth on test data for UTOPIA is 0.0011582607111932403
# The overall coverage for LQR is 0.9010989010989011
# Mean bandwidth on test data for LQR is 0.0014247420676682665
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.0025443856343907827
# 58 th index is done!
# The overall coverage for UTOPIA is 0.8681318681318682
# Mean bandwidth on test data for UTOPIA is 0.02290794169147208
# The overall coverage for LQR is 0.7802197802197802
# Mean bandwidth on test data for LQR is 0.005037089384625586
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.004157771997752415
# 59 th index is done!
# The overall coverage for UTOPIA is 0.8131868131868132
# Mean bandwidth on test data for UTOPIA is 0.00028031177642769475
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.0004477143825790988
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002469567253010303
# 60 th index is done!
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.00017096168334044677
# The overall coverage for LQR is 0.7362637362637363
# Mean bandwidth on test data for LQR is 0.00021356144537555585
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0021868451362511278
# 61 th index is done!
# The overall coverage for UTOPIA is 0.7472527472527473
# Mean bandwidth on test data for UTOPIA is 0.0004778005724743104
# The overall coverage for LQR is 0.7582417582417582
# Mean bandwidth on test data for LQR is 0.0004191243511983759
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002329556872483103
# 62 th index is done!
# The overall coverage for UTOPIA is 0.8571428571428571
# Mean bandwidth on test data for UTOPIA is 0.0010069018944966418
# The overall coverage for LQR is 0.8791208791208791
# Mean bandwidth on test data for LQR is 0.0006907176092639788
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0023213342647368175
# 63 th index is done!
# The overall coverage for UTOPIA is 0.8681318681318682
# Mean bandwidth on test data for UTOPIA is 0.0002709620395652061
# The overall coverage for LQR is 0.6153846153846154
# Mean bandwidth on test data for LQR is 0.00014256155050668755
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.0023251415489924853
# 64 th index is done!
# The overall coverage for UTOPIA is 0.7142857142857143
# Mean bandwidth on test data for UTOPIA is 0.00014758082800194193
# The overall coverage for LQR is 0.6153846153846154
# Mean bandwidth on test data for LQR is 0.00012431306857736089
# The overall coverage for SplitCF is 0.5604395604395604
# Mean bandwidth on test data for SplitCF is 0.003309655733738499
# 65 th index is done!
# The overall coverage for UTOPIA is 0.6593406593406593
# Mean bandwidth on test data for UTOPIA is 0.00048489759063576017
# The overall coverage for LQR is 0.8681318681318682
# Mean bandwidth on test data for LQR is 0.0010811455034493503
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0022890242198996854
# 66 th index is done!
# The overall coverage for UTOPIA is 0.9560439560439561
# Mean bandwidth on test data for UTOPIA is 0.0006035607004942614
# The overall coverage for LQR is 1.0
# Mean bandwidth on test data for LQR is 0.007244551434361214
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002373875437151067
# 67 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 0.0009517072192069975
# The overall coverage for LQR is 0.8131868131868132
# Mean bandwidth on test data for LQR is 0.001032250601878286
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.00412949810232603
# 68 th index is done!
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.00014824162331348266
# The overall coverage for LQR is 0.5164835164835165
# Mean bandwidth on test data for LQR is 9.79544245107672e-05
# The overall coverage for SplitCF is 0.6043956043956044
# Mean bandwidth on test data for SplitCF is 0.004220555019262593
# 69 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 0.00040049456290509563
# The overall coverage for LQR is 0.7692307692307693
# Mean bandwidth on test data for LQR is 0.00025639966227334726
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002319315283965894
# 70 th index is done!
# The overall coverage for UTOPIA is 0.7252747252747253
# Mean bandwidth on test data for UTOPIA is 0.0002107502221581946
# The overall coverage for LQR is 0.7362637362637363
# Mean bandwidth on test data for LQR is 0.0002484642384692329
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.004099649928716602
# 71 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.8131868131868132
# Mean bandwidth on test data for UTOPIA is 0.00018716442195082693
# The overall coverage for LQR is 0.4945054945054945
# Mean bandwidth on test data for LQR is 0.00012237729620911286
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.0025423051530061914
# 72 th index is done!
# The overall coverage for UTOPIA is 0.8351648351648352
# Mean bandwidth on test data for UTOPIA is 0.00029209324976607257
# The overall coverage for LQR is 0.7582417582417582
# Mean bandwidth on test data for LQR is 0.00030705423316092917
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.0025444478911147905
# 73 th index is done!
# The overall coverage for UTOPIA is 0.8351648351648352
# Mean bandwidth on test data for UTOPIA is 0.0003646368719815483
# The overall coverage for LQR is 0.6373626373626373
# Mean bandwidth on test data for LQR is 0.00014610048634262787
# The overall coverage for SplitCF is 0.6263736263736264
# Mean bandwidth on test data for SplitCF is 0.003512258728140816
# 74 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 0.005122643735786597
# The overall coverage for LQR is 0.5934065934065934
# Mean bandwidth on test data for LQR is 0.0015339700235727286
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.0045745413353780115
# 75 th index is done!
# The overall coverage for UTOPIA is 0.978021978021978
# Mean bandwidth on test data for UTOPIA is 0.003839667404106648
# The overall coverage for LQR is 1.0
# Mean bandwidth on test data for LQR is 0.023365040201937987
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023066631684256363
# 76 th index is done!
# The overall coverage for UTOPIA is 0.989010989010989
# Mean bandwidth on test data for UTOPIA is 0.05000081006534005
# The overall coverage for LQR is 0.4175824175824176
# Mean bandwidth on test data for LQR is 0.002460689001458032
# The overall coverage for SplitCF is 0.6043956043956044
# Mean bandwidth on test data for SplitCF is 0.004344519265782366
# 77 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 0.02104787177346366
# The overall coverage for LQR is 0.45054945054945056
# Mean bandwidth on test data for LQR is 0.0024209754653473923
# The overall coverage for SplitCF is 0.6813186813186813
# Mean bandwidth on test data for SplitCF is 0.004861900224241742
# 78 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 0.02001797744852238
# The overall coverage for LQR is 0.8021978021978022
# Mean bandwidth on test data for LQR is 0.006680055387707161
# The overall coverage for SplitCF is 0.6813186813186813
# Mean bandwidth on test data for SplitCF is 0.00486190037930833
# 79 th index is done!
# The overall coverage for UTOPIA is 0.967032967032967
# Mean bandwidth on test data for UTOPIA is 0.00711493979596127
# The overall coverage for LQR is 0.43956043956043955
# Mean bandwidth on test data for LQR is 0.0007797041677038066
# The overall coverage for SplitCF is 0.5824175824175825
# Mean bandwidth on test data for SplitCF is 0.004634955071357836
# 80 th index is done!
# The overall coverage for UTOPIA is 0.6703296703296703
# Mean bandwidth on test data for UTOPIA is 0.002157952592722967
# The overall coverage for LQR is 0.8021978021978022
# Mean bandwidth on test data for LQR is 0.0036558385118185765
# The overall coverage for SplitCF is 0.6043956043956044
# Mean bandwidth on test data for SplitCF is 0.004614541604834736
# 81 th index is done!
# The overall coverage for UTOPIA is 0.8791208791208791
# Mean bandwidth on test data for UTOPIA is 0.007194948691253948
# The overall coverage for LQR is 0.8901098901098901
# Mean bandwidth on test data for LQR is 0.008422382766002904
# The overall coverage for SplitCF is 0.6923076923076923
# Mean bandwidth on test data for SplitCF is 0.005563589337952243
# 82 th index is done!
# The overall coverage for UTOPIA is 0.978021978021978
# Mean bandwidth on test data for UTOPIA is 0.012161390130590364
# The overall coverage for LQR is 0.8131868131868132
# Mean bandwidth on test data for LQR is 0.005678160459517388
# The overall coverage for SplitCF is 0.6263736263736264
# Mean bandwidth on test data for SplitCF is 0.00415128872288049
# 83 th index is done!
# The overall coverage for UTOPIA is 0.978021978021978
# Mean bandwidth on test data for UTOPIA is 0.01937202370440468
# The overall coverage for LQR is 0.978021978021978
# Mean bandwidth on test data for LQR is 0.017409607948198624
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.003121054213578941
# 84 th index is done!
# The overall coverage for UTOPIA is 0.989010989010989
# Mean bandwidth on test data for UTOPIA is 0.04871623358346615
# The overall coverage for LQR is 0.967032967032967
# Mean bandwidth on test data for LQR is 0.024423696374000724
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.004179955603620322
# 85 th index is done!
# The overall coverage for UTOPIA is 0.6373626373626373
# Mean bandwidth on test data for UTOPIA is 0.008307216661250115
# The overall coverage for LQR is 1.0
# Mean bandwidth on test data for LQR is 0.38819971521845564
# The overall coverage for SplitCF is 0.5824175824175825
# Mean bandwidth on test data for SplitCF is 0.010857682799905155
# 86 th index is done!
# The overall coverage for UTOPIA is 0.9560439560439561
# Mean bandwidth on test data for UTOPIA is 0.01812439035709707
# The overall coverage for LQR is 0.26373626373626374
# Mean bandwidth on test data for LQR is 0.0008241220573043707
# The overall coverage for SplitCF is 0.23076923076923078
# Mean bandwidth on test data for SplitCF is 0.017747920498666882
# 87 th index is done!
# The overall coverage for UTOPIA is 0.5494505494505495
# Mean bandwidth on test data for UTOPIA is 0.024203044318234043
# The overall coverage for LQR is 0.18681318681318682
# Mean bandwidth on test data for LQR is 0.00267094971580364
# The overall coverage for SplitCF is 0.5384615384615384
# Mean bandwidth on test data for SplitCF is 0.006990716283868669
# 88 th index is done!
# The overall coverage for UTOPIA is 0.6703296703296703
# Mean bandwidth on test data for UTOPIA is 0.023923394607270474
# The overall coverage for LQR is 0.34065934065934067
# Mean bandwidth on test data for LQR is 0.008597909153548305
# The overall coverage for SplitCF is 0.6813186813186813
# Mean bandwidth on test data for SplitCF is 0.018790007450762987
# 89 th index is done!
# The overall coverage for UTOPIA is 0.32967032967032966
# Mean bandwidth on test data for UTOPIA is 0.07579515519323272
# The overall coverage for LQR is 0.945054945054945
# Mean bandwidth on test data for LQR is 0.23921188383228853
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.009846091656674258
# 90 th index is done!
# The overall coverage for UTOPIA is 0.7252747252747253
# Mean bandwidth on test data for UTOPIA is 0.18332791451782715
# The overall coverage for LQR is 0.978021978021978
# Mean bandwidth on test data for LQR is 0.2576549119130908
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.006000267505175086
# 91 th index is done!
# The overall coverage for UTOPIA is 0.9560439560439561
# Mean bandwidth on test data for UTOPIA is 1.2142757540549312
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.9870621436695476
# The overall coverage for SplitCF is 0.3956043956043956
# Mean bandwidth on test data for SplitCF is 0.006721415855190639
# 92 th index is done!
# The overall coverage for UTOPIA is 0.945054945054945
# Mean bandwidth on test data for UTOPIA is 2.1418121447641063
# The overall coverage for LQR is 0.5604395604395604
# Mean bandwidth on test data for LQR is 0.2716782036397961
# The overall coverage for SplitCF is 0.5714285714285714
# Mean bandwidth on test data for SplitCF is 0.005267713342968007
# 93 th index is done!
# The overall coverage for UTOPIA is 0.7802197802197802
# Mean bandwidth on test data for UTOPIA is 0.00036002968134394734
# The overall coverage for LQR is 0.7692307692307693
# Mean bandwidth on test data for LQR is 0.0004136795259794694
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0022330501277653026
# 94 th index is done!
# The overall coverage for UTOPIA is 0.9010989010989011
# Mean bandwidth on test data for UTOPIA is 0.0007243118970962638
# The overall coverage for LQR is 0.7142857142857143
# Mean bandwidth on test data for LQR is 0.00044714688445965026
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.002259754286207353
# 95 th index is done!
# The overall coverage for UTOPIA is 0.9340659340659341
# Mean bandwidth on test data for UTOPIA is 0.0029681734588393443
# The overall coverage for LQR is 0.8901098901098901
# Mean bandwidth on test data for LQR is 0.0027530932488351676
# The overall coverage for SplitCF is 0.16483516483516483
# Mean bandwidth on test data for SplitCF is 0.002295072847800832
# 96 th index is done!
# The overall coverage for UTOPIA is 0.6703296703296703
# Mean bandwidth on test data for UTOPIA is 0.000503524019715354
# The overall coverage for LQR is 0.6923076923076923
# Mean bandwidth on test data for LQR is 0.0005342458715545501
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.002307346985094223
# 97 th index is done!
# The overall coverage for UTOPIA is 0.7362637362637363
# Mean bandwidth on test data for UTOPIA is 0.0006163421046183819
# The overall coverage for LQR is 0.7802197802197802
# Mean bandwidth on test data for LQR is 0.0006906976451438247
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002331522298933446
# 98 th index is done!
# The overall coverage for UTOPIA is 0.6593406593406593
# Mean bandwidth on test data for UTOPIA is 0.00020954671546040413
# The overall coverage for LQR is 0.5274725274725275
# Mean bandwidth on test data for LQR is 0.00014987899836709924
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023551139927430434
# 99 th index is done!
# The overall coverage for UTOPIA is 0.8021978021978022
# Mean bandwidth on test data for UTOPIA is 0.0002928190652898294
# The overall coverage for LQR is 0.4835164835164835
# Mean bandwidth on test data for LQR is 0.00013774506683467168
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002349275942369038
# 100 th index is done!
# The overall coverage for UTOPIA is 0.8461538461538461
# Mean bandwidth on test data for UTOPIA is 0.00026067253271026613
# The overall coverage for LQR is 0.8571428571428571
# Mean bandwidth on test data for LQR is 0.0002930409488225784
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023184410625703635
# 101 th index is done!
# The overall coverage for UTOPIA is 0.6153846153846154
# Mean bandwidth on test data for UTOPIA is 0.0016166927690336665
# The overall coverage for LQR is 1.0
# Mean bandwidth on test data for LQR is 0.020556366436676562
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002310780253353153
# 102 th index is done!
# The overall coverage for UTOPIA is 0.6813186813186813
# Mean bandwidth on test data for UTOPIA is 0.012914517852265366
# The overall coverage for LQR is 0.8681318681318682
# Mean bandwidth on test data for LQR is 0.038073911589642975
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023184410948221346
# 103 th index is done!
# The overall coverage for UTOPIA is 0.9560439560439561
# Mean bandwidth on test data for UTOPIA is 0.006171640782248256
# The overall coverage for LQR is 0.989010989010989
# Mean bandwidth on test data for LQR is 0.010419704376629969
# The overall coverage for SplitCF is 0.5054945054945055
# Mean bandwidth on test data for SplitCF is 0.0023059035766426275
# 104 th index is done!
# The overall coverage for UTOPIA is 0.8021978021978022
# Mean bandwidth on test data for UTOPIA is 0.0001875673245446068
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.0001328147108597083
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0023301933609228653
# 105 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.00022721001634071035
# The overall coverage for LQR is 0.7802197802197802
# Mean bandwidth on test data for LQR is 0.0002605148418999098
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.0022913860435218466
# 106 th index is done!
# The overall coverage for UTOPIA is 0.7252747252747253
# Mean bandwidth on test data for UTOPIA is 0.00027507987517311276
# The overall coverage for LQR is 0.3516483516483517
# Mean bandwidth on test data for LQR is 0.0001154697996358376
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.002298181643615258
# 107 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.00019728562971255468
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.0001629233484086842
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0022047764882583594
# 108 th index is done!
# The overall coverage for UTOPIA is 0.6043956043956044
# Mean bandwidth on test data for UTOPIA is 0.00016981998749681482
# The overall coverage for LQR is 0.5054945054945055
# Mean bandwidth on test data for LQR is 0.0001147961289163224
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.00228080158256554
# 109 th index is done!
# The overall coverage for UTOPIA is 0.5164835164835165
# Mean bandwidth on test data for UTOPIA is 0.00017128446539391853
# The overall coverage for LQR is 0.5604395604395604
# Mean bandwidth on test data for LQR is 0.00014713293004398718
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.002343423594669183
# 110 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.0001814053763959844
# The overall coverage for LQR is 0.5274725274725275
# Mean bandwidth on test data for LQR is 0.000130123366011963
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002306691203823418
# 111 th index is done!
# /home/jg5300/.conda/envs/torch-env/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# The overall coverage for UTOPIA is 0.9230769230769231
# Mean bandwidth on test data for UTOPIA is 0.0002034282713646593
# The overall coverage for LQR is 0.4835164835164835
# Mean bandwidth on test data for LQR is 0.00011987542674033671
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0023203090369158927
# 112 th index is done!
# The overall coverage for UTOPIA is 0.7362637362637363
# Mean bandwidth on test data for UTOPIA is 0.00021804565915999944
# The overall coverage for LQR is 0.7362637362637363
# Mean bandwidth on test data for LQR is 0.00021166104690329316
# The overall coverage for SplitCF is 0.6593406593406593
# Mean bandwidth on test data for SplitCF is 0.004059242754133903
# 113 th index is done!
# The overall coverage for UTOPIA is 0.6043956043956044
# Mean bandwidth on test data for UTOPIA is 0.000174256439065513
# The overall coverage for LQR is 0.5274725274725275
# Mean bandwidth on test data for LQR is 0.0001291381529610944
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.00232129393935113
# 114 th index is done!
# The overall coverage for UTOPIA is 0.7912087912087912
# Mean bandwidth on test data for UTOPIA is 0.00022876645981845554
# The overall coverage for LQR is 0.5604395604395604
# Mean bandwidth on test data for LQR is 0.00015449539772819545
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002325398556536551
# 115 th index is done!
# The overall coverage for UTOPIA is 0.5604395604395604
# Mean bandwidth on test data for UTOPIA is 0.00017121100223654824
# The overall coverage for LQR is 0.6153846153846154
# Mean bandwidth on test data for LQR is 0.00015547050061299754
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002233468285610184
# 116 th index is done!
# The overall coverage for UTOPIA is 0.7032967032967034
# Mean bandwidth on test data for UTOPIA is 0.00017844986826892655
# The overall coverage for LQR is 0.5494505494505495
# Mean bandwidth on test data for LQR is 0.0001220804726297862
# The overall coverage for SplitCF is 0.4835164835164835
# Mean bandwidth on test data for SplitCF is 0.002298181643906546
# 117 th index is done!
# The overall coverage for UTOPIA is 0.5054945054945055
# Mean bandwidth on test data for UTOPIA is 0.00015325469858548245
# The overall coverage for LQR is 0.5384615384615384
# Mean bandwidth on test data for LQR is 0.00012265808131344913
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.002290257229844227
# 118 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.00020494532386235888
# The overall coverage for LQR is 0.5164835164835165
# Mean bandwidth on test data for LQR is 0.00012762445168971515
# The overall coverage for SplitCF is 0.4945054945054945
# Mean bandwidth on test data for SplitCF is 0.0023633691846881274
# 119 th index is done!
# The overall coverage for UTOPIA is 0.7252747252747253
# Mean bandwidth on test data for UTOPIA is 0.00036941803479757714
# The overall coverage for LQR is 0.6263736263736264
# Mean bandwidth on test data for LQR is 0.00018136325598836682
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.002165590253576776
# 120 th index is done!
# The overall coverage for UTOPIA is 0.6923076923076923
# Mean bandwidth on test data for UTOPIA is 0.00020179981252550094
# The overall coverage for LQR is 0.5714285714285714
# Mean bandwidth on test data for LQR is 0.00014965032035132766
# The overall coverage for SplitCF is 0.5164835164835165
# Mean bandwidth on test data for SplitCF is 0.002450855891590439
# 121 th index is done!
# The overall coverage for UTOPIA is 0.9120879120879121
# Mean bandwidth on test data for UTOPIA is 41.024514318408464
# The overall coverage for LQR is 0.978021978021978
# Mean bandwidth on test data for LQR is 77.86746303783414
# The overall coverage for SplitCF is 0.4725274725274725
# Mean bandwidth on test data for SplitCF is 0.0023068841442889965
# 122 th index is done!
# The overall coverage for UTOPIA is 0.989010989010989
# Mean bandwidth on test data for UTOPIA is 0.002470181665567437
# The overall coverage for LQR is 1.0
# Mean bandwidth on test data for LQR is 0.003816345049678991
# The overall coverage for SplitCF is 0.45054945054945056
# Mean bandwidth on test data for SplitCF is 0.002366509184721801
# 123 th index is done!
# The overall coverage for UTOPIA is 0.8901098901098901
# Mean bandwidth on test data for UTOPIA is 0.0013896059488663283
# The overall coverage for LQR is 0.6703296703296703
# Mean bandwidth on test data for LQR is 0.00026359921997327397
# The overall coverage for SplitCF is 0.46153846153846156
# Mean bandwidth on test data for SplitCF is 0.0024049610295045457
# 124 th index is done!
# The overall coverage for UTOPIA is 0.6703296703296703
# Mean bandwidth on test data for UTOPIA is 0.0002956255135452698
# The overall coverage for LQR is 0.9230769230769231
# Mean bandwidth on test data for LQR is 0.0006048841772434132
# The overall coverage for SplitCF is 0.6483516483516484
# Mean bandwidth on test data for SplitCF is 0.003984937069522167
# 125 th index is done!
# The overall coverage for UTOPIA is 0.42857142857142855
# Mean bandwidth on test data for UTOPIA is 67.09833100174902
# The overall coverage for LQR is 0.9340659340659341
# Mean bandwidth on test data for LQR is 233.23521965656084
# The overall coverage for SplitCF is 0.18681318681318682
# Mean bandwidth on test data for SplitCF is 0.002294556476387321
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 12
#       9 X_test,Y_test,M_test,V_test,coverage_lqr, bandwidth_lqr = LQR_FRED_MD_MULTIVARIATE(Data)
#      10 X_test,Y_test,M_test,V_test, coverage_split, bandwidth_split = SplitCF_FRED_MD_MULTIVARIATE(Data)
# ---> 12 output_coverage[j,] = np.array([coverage_utopia, coverage_lqr, coverage_split]).reshape(-1)
#      13 output_bandwidth[j,] = np.array([bandwidth_utopia, bandwidth_lqr, bandwidth_split]).reshape(-1)
#      14 print(j, "th index is done!")
#
# IndexError: index 126 is out of bounds for axis 0 with size 126

# %%
idx = np.where(output_coverage[:,0] > 0.945)[0]
print(data.columns[idx])
print(output_coverage[idx,:])
print(output_bandwidth[idx,:])
# Out:
# Index(['IPFUELS', 'UEMP15OV', 'HOUST', 'HOUSTNE', 'HOUSTMW', 'HOUSTS',
#        'PERMIT', 'PERMITNE', 'PERMITMW', 'PERMITS', 'TOTRESNS',
#        'S.P.div.yield', 'S.P.PE.ratio', 'FEDFUNDS', 'CP3Mx', 'TB3MS', 'TB6MS',
#        'GS10', 'AAA', 'BAA', 'TB3SMFFM', 'AAAFFM', 'BAAFFM', 'PPICMM',
#        'DTCOLNVHFNM'],
#       dtype='object')
# [[0.96703297 0.58241758 0.1978022 ]
#  [0.94505495 0.8021978  0.46153846]
#  [0.94505495 0.         0.46153846]
#  [0.96703297 0.08791209 0.46153846]
#  [0.95604396 0.         0.53846154]
#  [0.96703297 0.         0.46153846]
#  [0.97802198 0.         0.46153846]
#  [0.98901099 0.07692308 0.45054945]
#  [0.96703297 0.         0.57142857]
#  [0.96703297 0.         0.46153846]
#  [0.95604396 1.         0.49450549]
#  [0.94505495 0.59340659 0.65934066]
#  [0.97802198 1.         0.47252747]
#  [0.98901099 0.41758242 0.6043956 ]
#  [0.94505495 0.45054945 0.68131868]
#  [0.94505495 0.8021978  0.68131868]
#  [0.96703297 0.43956044 0.58241758]
#  [0.97802198 0.81318681 0.62637363]
#  [0.97802198 0.97802198 0.53846154]
#  [0.98901099 0.96703297 0.65934066]
#  [0.95604396 0.26373626 0.23076923]
#  [0.95604396 0.85714286 0.3956044 ]
#  [0.94505495 0.56043956 0.57142857]
#  [0.95604396 0.98901099 0.50549451]
#  [0.98901099 1.         0.45054945]]
# [[1.88399355e-03 3.84823488e-04 2.11260300e-03]
#  [1.58216170e-03 6.33646254e-04 2.32474177e-03]
#  [7.47713500e+00 2.64668127e+00 2.62466579e-03]
#  [3.97374022e+00 1.19824800e+00 2.62570542e-03]
#  [6.43888548e+00 7.36100134e-01 4.53348096e-03]
#  [6.09271921e+00 1.79684734e+00 2.62499421e-03]
#  [8.67529535e+00 2.27089244e+00 2.62457328e-03]
#  [4.61529734e+00 1.10018884e+00 2.57248127e-03]
#  [5.68560228e+00 9.15055254e-01 3.47089161e-03]
#  [5.25305338e+00 1.38152191e+00 2.62500721e-03]
#  [6.03560700e-04 7.24455143e-03 2.37387544e-03]
#  [5.12264374e-03 1.53397002e-03 4.57454134e-03]
#  [3.83966740e-03 2.33650402e-02 2.30666317e-03]
#  [5.00008101e-02 2.46068900e-03 4.34451927e-03]
#  [2.10478718e-02 2.42097547e-03 4.86190022e-03]
#  [2.00179774e-02 6.68005539e-03 4.86190038e-03]
#  [7.11493980e-03 7.79704168e-04 4.63495507e-03]
#  [1.21613901e-02 5.67816046e-03 4.15128872e-03]
#  [1.93720237e-02 1.74096079e-02 3.12105421e-03]
#  [4.87162336e-02 2.44236964e-02 4.17995560e-03]
#  [1.81243904e-02 8.24122057e-04 1.77479205e-02]
#  [1.21427575e+00 9.87062144e-01 6.72141586e-03]
#  [2.14181214e+00 2.71678204e-01 5.26771334e-03]
#  [6.17164078e-03 1.04197044e-02 2.30590358e-03]
#  [2.47018167e-03 3.81634505e-03 2.36650918e-03]]
